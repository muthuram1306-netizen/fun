# %%
Python codes
1.You have a csv file named weather_Data.csv containing daily weather data for a city
2.Write a python script using pandas for student performance analysis
3.Write a python script for flight data analysis
4a.Write a program to calculate euclidean distance for two points in 2d space and dot product for two matrixusing the mathematical formulas
4b. write a program to work with time series data using numpy and pandas
A time series dataset representing daily temperatures over a year
5.Write a simple Python program using pandas that creates a dataframe performs the following basic operations and prints the result
6.Signal classification using machine learning
7.Write a program to classify a component is defective or not based on Voltage and Current using KNn 
8.Write a program to predict final exam scores based on features like study hours and final exam score using linear regression.
9.Write a program to build a machine learning linear regression model to predict the price of a house for 2025 based on features.FutureWarning
10.Write a program to develop a deciso tree classifier to predict signal quality
11.Write a program to generate a synthetic dataset representing electronic components based on their voltage and current characteristics using kmeans clustering
12a.Write a python program to analyse the score of 20 students in a class.Your analysis should include
12b.Write a python program to solve a system of linear equations represented by 
13 a.Write a python program using numpy to analyse your daily step count data collected over the past month the program should
13 b.Write a python program using numpy to analys the grades of 30 students across three subjects
14.a.write a python program to calculate the total impedance of an electrical circuit using the given impedance
14.b.A stock analyst is analysing two stocks 
15a.Write a program using pandas to -load and organize egg publish_display_data
15bThe dictionary containing information about products is an inventory 
16a Write a python program using pandas to perform the following tasks-read the csv file into a pandas dataframe
16bThe health care_Data.csv
